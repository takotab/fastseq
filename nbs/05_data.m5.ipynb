# %%
# default_exp data.m5

# %%
# hide
import sys

sys.path.append("..")
import pandas as pd
# Out:
# /home/tako/dev/env37/lib/python3.7/site-packages/pandas/compat/__init__.py:117: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
# hide
from nbdev.showdoc import *

# %%
from fastseq.data.all import *
from fastseq.core import *
from fastcore.all import *
from fastcore.imports import *
from fastai2.basics import *
from fastai2.data.transforms import *
from fastai2.tabular.core import *

# %% [markdown]
# # M5 Example

# %%
path = Path('../data/m5_tiny')
path.ls()
# Out:
# (#6) [Path('../data/m5_tiny/sales_train_validation.csv'),Path('../data/m5_tiny/sample_submission.csv'),Path('../data/m5_tiny/calendar.csv'),Path('../data/m5_tiny/prices.csv'),Path('../data/m5_tiny/rows'),Path('../data/m5_tiny/calender_d.csv')]

# %%
lookback, horizon = 28*2, 28
dl =  MTSDataLoaders.from_path(path / 'rows','sales', horizon = horizon, lookback = lookback, )

# %%
for o in dl.train:
    print({str(type(a))+str(i):a.shape for i,a in enumerate(o)})
    break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-b6cd77ac4429> in <module>
#       1 for o in dl.train:
# ----> 2     print({str(type(a))+str(i):a.shape for i,a in enumerate(r)})
#       3     break
#
# NameError: name 'r' is not defined

# %%
dl.show_batch(max_n=9)
# Out:
# Train:305088; Valid: 7224
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-077a6df744ae> in <module>
#       1 lookback, horizon = 28*2, 28
#       2 dl =  MTSDataLoaders.from_path(path / 'rows','sales', horizon = horizon, lookback = lookback, )
# ----> 3 dl.show_batch(max_n=9)
#
# ~/dev/fastseq/fastseq/data/load.py in _show_batch_class(self, b, max_n, ctxs, show, **kwargs)
#     409     if b is None: b = self.one_batch()
#     410     x, y, its = self._pre_show_batch(b, max_n=max_n)
# --> 411     x = self.after_item.decode(TSMulti_(x))
#     412     if not show: return x, y, its
#     413     show_batch(x,y,its, ctxs=ctxs, max_n=max_n, **kwargs)
#
# ~/dev/env37/lib/python3.7/site-packages/fastcore/transform.py in decode(self, o, full)
#     191
#     192     def decode  (self, o, full=True):
# ...
